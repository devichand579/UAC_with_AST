# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install -qqq tensorflow_addons
# !pip install -qqq tensorflow-io
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 611.8/611.8 kB 6.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 28.8/28.8 MB 56.9 MB/s eta 0:00:00

# %%
import tensorflow as tf
import tensorflow_io as tfio
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow_addons import layers as addon_layers

# Setting logger level to avoid input shape warnings
tf.get_logger().setLevel("ERROR")

# Defining hyperparameters

DESIRED_SAMPLES = 26368
LEARNING_RATE_GEN = 1e-5
LEARNING_RATE_DISC = 1e-6
BATCH_SIZE = 16

mse = keras.losses.MeanSquaredError()
mae = keras.losses.MeanAbsoluteError()
# Out:
# /usr/local/lib/python3.10/dist-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(

# %%
# Splitting the dataset into training and testing splits
wavs = tf.io.gfile.glob("/content/drive/MyDrive/train_data_real/class_E/*.wav")
print(f"Number of audio files: {len(wavs)}")

# Mapper function for loading the audio. This function returns two instances of the wave
def preprocess(filename):
    audio = tf.audio.decode_wav(tf.io.read_file(filename), 1, DESIRED_SAMPLES).audio
    return audio, audio


# Create tf.data.Dataset objects and apply preprocessing
train_dataset = tf.data.Dataset.from_tensor_slices((wavs,))
train_dataset = train_dataset.map(preprocess, num_parallel_calls=tf.data.AUTOTUNE)
# Out:
# Number of audio files: 382

# %%
# Custom keras layer for on-the-fly audio to spectrogram conversion


class MelSpec(layers.Layer):
    def __init__(
        self,
        frame_length=1024,
        frame_step=256,
        fft_length=None,
        sampling_rate=52734,
        num_mel_channels=80,
        freq_min=0,
        freq_max=8192,
        **kwargs,
    ):
        super().__init__(**kwargs)
        self.frame_length = frame_length
        self.frame_step = frame_step
        self.fft_length = fft_length
        self.sampling_rate = sampling_rate
        self.num_mel_channels = num_mel_channels
        self.freq_min = freq_min
        self.freq_max = freq_max
        # Defining mel filter. This filter will be multiplied with the STFT output
        self.mel_filterbank = tf.signal.linear_to_mel_weight_matrix(
            num_mel_bins=self.num_mel_channels,
            num_spectrogram_bins=self.frame_length // 2 + 1,
            sample_rate=self.sampling_rate,
            lower_edge_hertz=self.freq_min,
            upper_edge_hertz=self.freq_max,
        )

    def call(self, audio, training=True):
        # We will only perform the transformation during training.
        if training:
            # Taking the Short Time Fourier Transform. Ensure that the audio is padded.
            # In the paper, the STFT output is padded using the 'REFLECT' strategy.
            stft = tf.signal.stft(
                tf.squeeze(audio, -1),
                self.frame_length,
                self.frame_step,
                self.fft_length,
                pad_end=True,
            )

            # Taking the magnitude of the STFT output
            magnitude = tf.abs(stft)

            # Multiplying the Mel-filterbank with the magnitude and scaling it using the db scale
            mel = tf.matmul(tf.square(magnitude), self.mel_filterbank)
            log_mel_spec = tfio.audio.dbscale(mel, top_db=80)
            return log_mel_spec
        else:
            return audio

    def get_config(self):
        config = super().get_config()
        config.update(
            {
                "frame_length": self.frame_length,
                "frame_step": self.frame_step,
                "fft_length": self.fft_length,
                "sampling_rate": self.sampling_rate,
                "num_mel_channels": self.num_mel_channels,
                "freq_min": self.freq_min,
                "freq_max": self.freq_max,
            }
        )
        return config

# %%
# Creating the residual stack block


def residual_stack(input, filters):
    """Convolutional residual stack with weight normalization.

    Args:
        filters: int, determines filter size for the residual stack.

    Returns:
        Residual stack output.
    """
    c1 = addon_layers.WeightNormalization(
        layers.Conv1D(filters, 3, dilation_rate=1, padding="same"), data_init=False
    )(input)
    lrelu1 = layers.LeakyReLU()(c1)
    c2 = addon_layers.WeightNormalization(
        layers.Conv1D(filters, 3, dilation_rate=1, padding="same"), data_init=False
    )(lrelu1)
    add1 = layers.Add()([c2, input])

    lrelu2 = layers.LeakyReLU()(add1)
    c3 = addon_layers.WeightNormalization(
        layers.Conv1D(filters, 3, dilation_rate=3, padding="same"), data_init=False
    )(lrelu2)
    lrelu3 = layers.LeakyReLU()(c3)
    c4 = addon_layers.WeightNormalization(
        layers.Conv1D(filters, 3, dilation_rate=1, padding="same"), data_init=False
    )(lrelu3)
    add2 = layers.Add()([add1, c4])

    lrelu4 = layers.LeakyReLU()(add2)
    c5 = addon_layers.WeightNormalization(
        layers.Conv1D(filters, 3, dilation_rate=9, padding="same"), data_init=False
    )(lrelu4)
    lrelu5 = layers.LeakyReLU()(c5)
    c6 = addon_layers.WeightNormalization(
        layers.Conv1D(filters, 3, dilation_rate=1, padding="same"), data_init=False
    )(lrelu5)
    add3 = layers.Add()([c6, add2])

    return add3

# %%
# Dilated convolutional block consisting of the Residual stack


def conv_block(input, conv_dim, upsampling_factor):
    """Dilated Convolutional Block with weight normalization.

    Args:
        conv_dim: int, determines filter size for the block.
        upsampling_factor: int, scale for upsampling.

    Returns:
        Dilated convolution block.
    """
    conv_t = addon_layers.WeightNormalization(
        layers.Conv1DTranspose(conv_dim, 16, upsampling_factor, padding="same"),
        data_init=False,
    )(input)
    lrelu1 = layers.LeakyReLU()(conv_t)
    res_stack = residual_stack(lrelu1, conv_dim)
    lrelu2 = layers.LeakyReLU()(res_stack)
    return lrelu2

# %%
def discriminator_block(input):
    conv1 = addon_layers.WeightNormalization(
        layers.Conv1D(16, 15, 1, "same"), data_init=False
    )(input)
    lrelu1 = layers.LeakyReLU()(conv1)
    conv2 = addon_layers.WeightNormalization(
        layers.Conv1D(64, 41, 4, "same", groups=4), data_init=False
    )(lrelu1)
    lrelu2 = layers.LeakyReLU()(conv2)
    conv3 = addon_layers.WeightNormalization(
        layers.Conv1D(256, 41, 4, "same", groups=16), data_init=False
    )(lrelu2)
    lrelu3 = layers.LeakyReLU()(conv3)
    conv4 = addon_layers.WeightNormalization(
        layers.Conv1D(1024, 41, 4, "same", groups=64), data_init=False
    )(lrelu3)
    lrelu4 = layers.LeakyReLU()(conv4)
    conv5 = addon_layers.WeightNormalization(
        layers.Conv1D(1024, 41, 4, "same", groups=256), data_init=False
    )(lrelu4)
    lrelu5 = layers.LeakyReLU()(conv5)
    conv6 = addon_layers.WeightNormalization(
        layers.Conv1D(1024, 5, 1, "same"), data_init=False
    )(lrelu5)
    lrelu6 = layers.LeakyReLU()(conv6)
    conv7 = addon_layers.WeightNormalization(
        layers.Conv1D(1, 3, 1, "same"), data_init=False
    )(lrelu6)
    return [lrelu1, lrelu2, lrelu3, lrelu4, lrelu5, lrelu6, conv7]

# %%
def create_generator(input_shape):
    inp = keras.Input(input_shape)
    x = MelSpec()(inp)
    x = layers.Conv1D(512, 7, padding="same")(x)
    x = layers.LeakyReLU()(x)
    x = conv_block(x, 256, 8)
    x = conv_block(x, 128, 8)
    x = conv_block(x, 64, 2)
    x = conv_block(x, 32, 2)
    x = addon_layers.WeightNormalization(
        layers.Conv1D(1, 7, padding="same", activation="tanh")
    )(x)
    return keras.Model(inp, x)


# We use a dynamic input shape for the generator since the model is fully convolutional
generator = create_generator((None, 1))
generator.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, None, 1)]            0         []
#
#  mel_spec (MelSpec)          (None, None, 80)             0         ['input_1[0][0]']
#
#  conv1d (Conv1D)             (None, None, 512)            287232    ['mel_spec[0][0]']
#
#  leaky_re_lu (LeakyReLU)     (None, None, 512)            0         ['conv1d[0][0]']
#
#  weight_normalization (Weig  (None, None, 256)            2097921   ['leaky_re_lu[0][0]']
#  htNormalization)
#
#  leaky_re_lu_1 (LeakyReLU)   (None, None, 256)            0         ['weight_normalization[0][0]']
#
#  weight_normalization_1 (We  (None, None, 256)            197121    ['leaky_re_lu_1[0][0]']
#  ightNormalization)
#
#  leaky_re_lu_2 (LeakyReLU)   (None, None, 256)            0         ['weight_normalization_1[0][0]
#                                                                     ']
#
#  weight_normalization_2 (We  (None, None, 256)            197121    ['leaky_re_lu_2[0][0]']
#  ightNormalization)
#
#  add (Add)                   (None, None, 256)            0         ['weight_normalization_2[0][0]
#                                                                     ',
#                                                                      'leaky_re_lu_1[0][0]']
#
#  leaky_re_lu_3 (LeakyReLU)   (None, None, 256)            0         ['add[0][0]']
#
#  weight_normalization_3 (We  (None, None, 256)            197121    ['leaky_re_lu_3[0][0]']
#  ightNormalization)
#
#  leaky_re_lu_4 (LeakyReLU)   (None, None, 256)            0         ['weight_normalization_3[0][0]
#                                                                     ']
#
#  weight_normalization_4 (We  (None, None, 256)            197121    ['leaky_re_lu_4[0][0]']
#  ightNormalization)
#
#  add_1 (Add)                 (None, None, 256)            0         ['add[0][0]',
#                                                                      'weight_normalization_4[0][0]
#                                                                     ']
#
#  leaky_re_lu_5 (LeakyReLU)   (None, None, 256)            0         ['add_1[0][0]']
#
#  weight_normalization_5 (We  (None, None, 256)            197121    ['leaky_re_lu_5[0][0]']
#  ightNormalization)
#
#  leaky_re_lu_6 (LeakyReLU)   (None, None, 256)            0         ['weight_normalization_5[0][0]
#                                                                     ']
#
#  weight_normalization_6 (We  (None, None, 256)            197121    ['leaky_re_lu_6[0][0]']
#  ightNormalization)
#
#  add_2 (Add)                 (None, None, 256)            0         ['weight_normalization_6[0][0]
#                                                                     ',
#                                                                      'add_1[0][0]']
#
#  leaky_re_lu_7 (LeakyReLU)   (None, None, 256)            0         ['add_2[0][0]']
#
#  weight_normalization_7 (We  (None, None, 128)            524673    ['leaky_re_lu_7[0][0]']
#  ightNormalization)
#
#  leaky_re_lu_8 (LeakyReLU)   (None, None, 128)            0         ['weight_normalization_7[0][0]
#                                                                     ']
#
#  weight_normalization_8 (We  (None, None, 128)            49409     ['leaky_re_lu_8[0][0]']
#  ightNormalization)
#
#  leaky_re_lu_9 (LeakyReLU)   (None, None, 128)            0         ['weight_normalization_8[0][0]
#                                                                     ']
#
#  weight_normalization_9 (We  (None, None, 128)            49409     ['leaky_re_lu_9[0][0]']
#  ightNormalization)
#
#  add_3 (Add)                 (None, None, 128)            0         ['weight_normalization_9[0][0]
#                                                                     ',
#                                                                      'leaky_re_lu_8[0][0]']
#
#  leaky_re_lu_10 (LeakyReLU)  (None, None, 128)            0         ['add_3[0][0]']
#
#  weight_normalization_10 (W  (None, None, 128)            49409     ['leaky_re_lu_10[0][0]']
#  eightNormalization)
#
#  leaky_re_lu_11 (LeakyReLU)  (None, None, 128)            0         ['weight_normalization_10[0][0
#                                                                     ]']
#
#  weight_normalization_11 (W  (None, None, 128)            49409     ['leaky_re_lu_11[0][0]']
#  eightNormalization)
#
#  add_4 (Add)                 (None, None, 128)            0         ['add_3[0][0]',
#                                                                      'weight_normalization_11[0][0
#                                                                     ]']
#
#  leaky_re_lu_12 (LeakyReLU)  (None, None, 128)            0         ['add_4[0][0]']
#
#  weight_normalization_12 (W  (None, None, 128)            49409     ['leaky_re_lu_12[0][0]']
#  eightNormalization)
#
#  leaky_re_lu_13 (LeakyReLU)  (None, None, 128)            0         ['weight_normalization_12[0][0
#                                                                     ]']
#
#  weight_normalization_13 (W  (None, None, 128)            49409     ['leaky_re_lu_13[0][0]']
#  eightNormalization)
#
#  add_5 (Add)                 (None, None, 128)            0         ['weight_normalization_13[0][0
#                                                                     ]',
#                                                                      'add_4[0][0]']
#
#  leaky_re_lu_14 (LeakyReLU)  (None, None, 128)            0         ['add_5[0][0]']
#
#  weight_normalization_14 (W  (None, None, 64)             131265    ['leaky_re_lu_14[0][0]']
#  eightNormalization)
#
#  leaky_re_lu_15 (LeakyReLU)  (None, None, 64)             0         ['weight_normalization_14[0][0
#                                                                     ]']
#
#  weight_normalization_15 (W  (None, None, 64)             12417     ['leaky_re_lu_15[0][0]']
#  eightNormalization)
#
#  leaky_re_lu_16 (LeakyReLU)  (None, None, 64)             0         ['weight_normalization_15[0][0
#                                                                     ]']
#
#  weight_normalization_16 (W  (None, None, 64)             12417     ['leaky_re_lu_16[0][0]']
#  eightNormalization)
#
#  add_6 (Add)                 (None, None, 64)             0         ['weight_normalization_16[0][0
#                                                                     ]',
#                                                                      'leaky_re_lu_15[0][0]']
#
#  leaky_re_lu_17 (LeakyReLU)  (None, None, 64)             0         ['add_6[0][0]']
#
#  weight_normalization_17 (W  (None, None, 64)             12417     ['leaky_re_lu_17[0][0]']
#  eightNormalization)
#
#  leaky_re_lu_18 (LeakyReLU)  (None, None, 64)             0         ['weight_normalization_17[0][0
#                                                                     ]']
#
#  weight_normalization_18 (W  (None, None, 64)             12417     ['leaky_re_lu_18[0][0]']
#  eightNormalization)
#
#  add_7 (Add)                 (None, None, 64)             0         ['add_6[0][0]',
#                                                                      'weight_normalization_18[0][0
#                                                                     ]']
#
#  leaky_re_lu_19 (LeakyReLU)  (None, None, 64)             0         ['add_7[0][0]']
#
#  weight_normalization_19 (W  (None, None, 64)             12417     ['leaky_re_lu_19[0][0]']
#  eightNormalization)
#
#  leaky_re_lu_20 (LeakyReLU)  (None, None, 64)             0         ['weight_normalization_19[0][0
#                                                                     ]']
#
#  weight_normalization_20 (W  (None, None, 64)             12417     ['leaky_re_lu_20[0][0]']
#  eightNormalization)
#
#  add_8 (Add)                 (None, None, 64)             0         ['weight_normalization_20[0][0
#                                                                     ]',
#                                                                      'add_7[0][0]']
#
#  leaky_re_lu_21 (LeakyReLU)  (None, None, 64)             0         ['add_8[0][0]']
#
#  weight_normalization_21 (W  (None, None, 32)             32865     ['leaky_re_lu_21[0][0]']
#  eightNormalization)
#
#  leaky_re_lu_22 (LeakyReLU)  (None, None, 32)             0         ['weight_normalization_21[0][0
#                                                                     ]']
#
#  weight_normalization_22 (W  (None, None, 32)             3137      ['leaky_re_lu_22[0][0]']
#  eightNormalization)
#
#  leaky_re_lu_23 (LeakyReLU)  (None, None, 32)             0         ['weight_normalization_22[0][0
#                                                                     ]']
#
#  weight_normalization_23 (W  (None, None, 32)             3137      ['leaky_re_lu_23[0][0]']
#  eightNormalization)
#
#  add_9 (Add)                 (None, None, 32)             0         ['weight_normalization_23[0][0
#                                                                     ]',
#                                                                      'leaky_re_lu_22[0][0]']
#
#  leaky_re_lu_24 (LeakyReLU)  (None, None, 32)             0         ['add_9[0][0]']
#
#  weight_normalization_24 (W  (None, None, 32)             3137      ['leaky_re_lu_24[0][0]']
#  eightNormalization)
#
#  leaky_re_lu_25 (LeakyReLU)  (None, None, 32)             0         ['weight_normalization_24[0][0
#                                                                     ]']
#
#  weight_normalization_25 (W  (None, None, 32)             3137      ['leaky_re_lu_25[0][0]']
#  eightNormalization)
#
#  add_10 (Add)                (None, None, 32)             0         ['add_9[0][0]',
#                                                                      'weight_normalization_25[0][0
#                                                                     ]']
#
#  leaky_re_lu_26 (LeakyReLU)  (None, None, 32)             0         ['add_10[0][0]']
#
#  weight_normalization_26 (W  (None, None, 32)             3137      ['leaky_re_lu_26[0][0]']
#  eightNormalization)
#
#  leaky_re_lu_27 (LeakyReLU)  (None, None, 32)             0         ['weight_normalization_26[0][0
#                                                                     ]']
#
#  weight_normalization_27 (W  (None, None, 32)             3137      ['leaky_re_lu_27[0][0]']
#  eightNormalization)
#
#  add_11 (Add)                (None, None, 32)             0         ['weight_normalization_27[0][0
#                                                                     ]',
#                                                                      'add_10[0][0]']
#
#  leaky_re_lu_28 (LeakyReLU)  (None, None, 32)             0         ['add_11[0][0]']
#
#  weight_normalization_28 (W  (None, None, 1)              452       ['leaky_re_lu_28[0][0]']
#  eightNormalization)
#
# ==================================================================================================
# Total params: 4646912 (17.73 MB)
# Trainable params: 4646658 (17.73 MB)
# Non-trainable params: 254 (929.00 Byte)
# __________________________________________________________________________________________________

# %%
def create_discriminator(input_shape):
    inp = keras.Input(input_shape)
    out_map1 = discriminator_block(inp)
    pool1 = layers.AveragePooling1D()(inp)
    out_map2 = discriminator_block(pool1)
    pool2 = layers.AveragePooling1D()(pool1)
    out_map3 = discriminator_block(pool2)
    return keras.Model(inp, [out_map1, out_map2, out_map3])


# We use a dynamic input shape for the discriminator
# This is done because the input shape for the generator is unknown
discriminator = create_discriminator((None, 1))

discriminator.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, None, 1)]            0         []
#
#  average_pooling1d (Average  (None, None, 1)              0         ['input_2[0][0]']
#  Pooling1D)
#
#  average_pooling1d_1 (Avera  (None, None, 1)              0         ['average_pooling1d[0][0]']
#  gePooling1D)
#
#  weight_normalization_29 (W  (None, None, 16)             273       ['input_2[0][0]']
#  eightNormalization)
#
#  weight_normalization_36 (W  (None, None, 16)             273       ['average_pooling1d[0][0]']
#  eightNormalization)
#
#  weight_normalization_43 (W  (None, None, 16)             273       ['average_pooling1d_1[0][0]']
#  eightNormalization)
#
#  leaky_re_lu_29 (LeakyReLU)  (None, None, 16)             0         ['weight_normalization_29[0][0
#                                                                     ]']
#
#  leaky_re_lu_35 (LeakyReLU)  (None, None, 16)             0         ['weight_normalization_36[0][0
#                                                                     ]']
#
#  leaky_re_lu_41 (LeakyReLU)  (None, None, 16)             0         ['weight_normalization_43[0][0
#                                                                     ]']
#
#  weight_normalization_30 (W  (None, None, 64)             10625     ['leaky_re_lu_29[0][0]']
#  eightNormalization)
#
#  weight_normalization_37 (W  (None, None, 64)             10625     ['leaky_re_lu_35[0][0]']
#  eightNormalization)
#
#  weight_normalization_44 (W  (None, None, 64)             10625     ['leaky_re_lu_41[0][0]']
#  eightNormalization)
#
#  leaky_re_lu_30 (LeakyReLU)  (None, None, 64)             0         ['weight_normalization_30[0][0
#                                                                     ]']
#
#  leaky_re_lu_36 (LeakyReLU)  (None, None, 64)             0         ['weight_normalization_37[0][0
#                                                                     ]']
#
#  leaky_re_lu_42 (LeakyReLU)  (None, None, 64)             0         ['weight_normalization_44[0][0
#                                                                     ]']
#
#  weight_normalization_31 (W  (None, None, 256)            42497     ['leaky_re_lu_30[0][0]']
#  eightNormalization)
#
#  weight_normalization_38 (W  (None, None, 256)            42497     ['leaky_re_lu_36[0][0]']
#  eightNormalization)
#
#  weight_normalization_45 (W  (None, None, 256)            42497     ['leaky_re_lu_42[0][0]']
#  eightNormalization)
#
#  leaky_re_lu_31 (LeakyReLU)  (None, None, 256)            0         ['weight_normalization_31[0][0
#                                                                     ]']
#
#  leaky_re_lu_37 (LeakyReLU)  (None, None, 256)            0         ['weight_normalization_38[0][0
#                                                                     ]']
#
#  leaky_re_lu_43 (LeakyReLU)  (None, None, 256)            0         ['weight_normalization_45[0][0
#                                                                     ]']
#
#  weight_normalization_32 (W  (None, None, 1024)           169985    ['leaky_re_lu_31[0][0]']
#  eightNormalization)
#
#  weight_normalization_39 (W  (None, None, 1024)           169985    ['leaky_re_lu_37[0][0]']
#  eightNormalization)
#
#  weight_normalization_46 (W  (None, None, 1024)           169985    ['leaky_re_lu_43[0][0]']
#  eightNormalization)
#
#  leaky_re_lu_32 (LeakyReLU)  (None, None, 1024)           0         ['weight_normalization_32[0][0
#                                                                     ]']
#
#  leaky_re_lu_38 (LeakyReLU)  (None, None, 1024)           0         ['weight_normalization_39[0][0
#                                                                     ]']
#
#  leaky_re_lu_44 (LeakyReLU)  (None, None, 1024)           0         ['weight_normalization_46[0][0
#                                                                     ]']
#
#  weight_normalization_33 (W  (None, None, 1024)           169985    ['leaky_re_lu_32[0][0]']
#  eightNormalization)
#
#  weight_normalization_40 (W  (None, None, 1024)           169985    ['leaky_re_lu_38[0][0]']
#  eightNormalization)
#
#  weight_normalization_47 (W  (None, None, 1024)           169985    ['leaky_re_lu_44[0][0]']
#  eightNormalization)
#
#  leaky_re_lu_33 (LeakyReLU)  (None, None, 1024)           0         ['weight_normalization_33[0][0
#                                                                     ]']
#
#  leaky_re_lu_39 (LeakyReLU)  (None, None, 1024)           0         ['weight_normalization_40[0][0
#                                                                     ]']
#
#  leaky_re_lu_45 (LeakyReLU)  (None, None, 1024)           0         ['weight_normalization_47[0][0
#                                                                     ]']
#
#  weight_normalization_34 (W  (None, None, 1024)           5244929   ['leaky_re_lu_33[0][0]']
#  eightNormalization)
#
#  weight_normalization_41 (W  (None, None, 1024)           5244929   ['leaky_re_lu_39[0][0]']
#  eightNormalization)
#
#  weight_normalization_48 (W  (None, None, 1024)           5244929   ['leaky_re_lu_45[0][0]']
#  eightNormalization)
#
#  leaky_re_lu_34 (LeakyReLU)  (None, None, 1024)           0         ['weight_normalization_34[0][0
#                                                                     ]']
#
#  leaky_re_lu_40 (LeakyReLU)  (None, None, 1024)           0         ['weight_normalization_41[0][0
#                                                                     ]']
#
#  leaky_re_lu_46 (LeakyReLU)  (None, None, 1024)           0         ['weight_normalization_48[0][0
#                                                                     ]']
#
#  weight_normalization_35 (W  (None, None, 1)              3075      ['leaky_re_lu_34[0][0]']
#  eightNormalization)
#
#  weight_normalization_42 (W  (None, None, 1)              3075      ['leaky_re_lu_40[0][0]']
#  eightNormalization)
#
#  weight_normalization_49 (W  (None, None, 1)              3075      ['leaky_re_lu_46[0][0]']
#  eightNormalization)
#
# ==================================================================================================
# Total params: 16924107 (64.56 MB)
# Trainable params: 16924086 (64.56 MB)
# Non-trainable params: 21 (21.00 Byte)
# __________________________________________________________________________________________________

# %%
# Generator loss


def generator_loss(real_pred, fake_pred):
    """Loss function for the generator.

    Args:
        real_pred: Tensor, output of the ground truth wave passed through the discriminator.
        fake_pred: Tensor, output of the generator prediction passed through the discriminator.

    Returns:
        Loss for the generator.
    """
    gen_loss = []
    for i in range(len(fake_pred)):
        gen_loss.append(mse(tf.ones_like(fake_pred[i][-1]), fake_pred[i][-1]))

    return tf.reduce_mean(gen_loss)


def feature_matching_loss(real_pred, fake_pred):
    """Implements the feature matching loss.

    Args:
        real_pred: Tensor, output of the ground truth wave passed through the discriminator.
        fake_pred: Tensor, output of the generator prediction passed through the discriminator.

    Returns:
        Feature Matching Loss.
    """
    fm_loss = []
    for i in range(len(fake_pred)):
        for j in range(len(fake_pred[i]) - 1):
            fm_loss.append(mae(real_pred[i][j], fake_pred[i][j]))

    return tf.reduce_mean(fm_loss)


def discriminator_loss(real_pred, fake_pred):
    """Implements the discriminator loss.

    Args:
        real_pred: Tensor, output of the ground truth wave passed through the discriminator.
        fake_pred: Tensor, output of the generator prediction passed through the discriminator.

    Returns:
        Discriminator Loss.
    """
    real_loss, fake_loss = [], []
    for i in range(len(real_pred)):
        real_loss.append(mse(tf.ones_like(real_pred[i][-1]), real_pred[i][-1]))
        fake_loss.append(mse(tf.zeros_like(fake_pred[i][-1]), fake_pred[i][-1]))

    # Calculating the final discriminator loss after scaling
    disc_loss = tf.reduce_mean(real_loss) + tf.reduce_mean(fake_loss)
    return disc_loss

# %%
class MelGAN(keras.Model):
    def __init__(self, generator, discriminator, **kwargs):
        """MelGAN trainer class

        Args:
            generator: keras.Model, Generator model
            discriminator: keras.Model, Discriminator model
        """
        super().__init__(**kwargs)
        self.generator = generator
        self.discriminator = discriminator

    def compile(
        self,
        gen_optimizer,
        disc_optimizer,
        generator_loss,
        feature_matching_loss,
        discriminator_loss,
    ):
        """MelGAN compile method.

        Args:
            gen_optimizer: keras.optimizer, optimizer to be used for training
            disc_optimizer: keras.optimizer, optimizer to be used for training
            generator_loss: callable, loss function for generator
            feature_matching_loss: callable, loss function for feature matching
            discriminator_loss: callable, loss function for discriminator
        """
        super().compile()

        # Optimizers
        self.gen_optimizer = gen_optimizer
        self.disc_optimizer = disc_optimizer

        # Losses
        self.generator_loss = generator_loss
        self.feature_matching_loss = feature_matching_loss
        self.discriminator_loss = discriminator_loss

        # Trackers
        self.gen_loss_tracker = keras.metrics.Mean(name="gen_loss")
        self.disc_loss_tracker = keras.metrics.Mean(name="disc_loss")

    def train_step(self, batch):
        x_batch_train, y_batch_train = batch

        with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
            # Generating the audio wave
            gen_audio_wave = generator(x_batch_train, training=True)
            # Generating the features using the discriminator
            real_pred = discriminator(y_batch_train)
            fake_pred = discriminator(gen_audio_wave)
            # Calculating the generator losses
            gen_loss = generator_loss(real_pred, fake_pred)
            fm_loss = feature_matching_loss(real_pred, fake_pred)

            # Calculating final generator loss
            gen_fm_loss = gen_loss + 10 * fm_loss

            # Calculating the discriminator losses
            disc_loss = discriminator_loss(real_pred, fake_pred)

        # Calculating and applying the gradients for generator and discriminator
        grads_gen = gen_tape.gradient(gen_fm_loss, generator.trainable_weights)
        grads_disc = disc_tape.gradient(disc_loss, discriminator.trainable_weights)
        gen_optimizer.apply_gradients(zip(grads_gen, generator.trainable_weights))
        disc_optimizer.apply_gradients(zip(grads_disc, discriminator.trainable_weights))

        self.gen_loss_tracker.update_state(gen_fm_loss)
        self.disc_loss_tracker.update_state(disc_loss)

        return {
            "gen_loss": self.gen_loss_tracker.result(),
            "disc_loss": self.disc_loss_tracker.result(),
        }

# %%
gen_optimizer = keras.optimizers.Adam(
    LEARNING_RATE_GEN, beta_1=0.5, beta_2=0.9, clipnorm=1
)
disc_optimizer = keras.optimizers.Adam(
    LEARNING_RATE_DISC, beta_1=0.5, beta_2=0.9, clipnorm=1
)

# Start training
generator = create_generator((None, 1))
discriminator = create_discriminator((None, 1))

mel_gan = MelGAN(generator, discriminator)
mel_gan.compile(
    gen_optimizer,
    disc_optimizer,
    generator_loss,
    feature_matching_loss,
    discriminator_loss,
)
mel_gan.fit(
    train_dataset.shuffle(200).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE), epochs=100
)
# Out:
# Epoch 1/100
# 24/24 [==============================] - 134s 1s/step - gen_loss: 1.0766 - disc_loss: 0.9990
# Epoch 2/100
# 24/24 [==============================] - 21s 881ms/step - gen_loss: 1.0444 - disc_loss: 0.9968
# Epoch 3/100
# 24/24 [==============================] - 21s 869ms/step - gen_loss: 1.0427 - disc_loss: 0.9944
# Epoch 4/100
# 24/24 [==============================] - 21s 879ms/step - gen_loss: 1.0343 - disc_loss: 0.9918
# Epoch 5/100
# 24/24 [==============================] - 21s 877ms/step - gen_loss: 1.0301 - disc_loss: 0.9890
# Epoch 6/100
# 24/24 [==============================] - 22s 901ms/step - gen_loss: 1.0331 - disc_loss: 0.9861
# Epoch 7/100
# 24/24 [==============================] - 23s 929ms/step - gen_loss: 1.0297 - disc_loss: 0.9829
# Epoch 8/100
# 24/24 [==============================] - 22s 907ms/step - gen_loss: 1.0217 - disc_loss: 0.9795
# Epoch 9/100
# 24/24 [==============================] - 22s 896ms/step - gen_loss: 1.0172 - disc_loss: 0.9759
# Epoch 10/100
# 24/24 [==============================] - 22s 886ms/step - gen_loss: 1.0095 - disc_loss: 0.9721
# Epoch 11/100
# 24/24 [==============================] - 22s 913ms/step - gen_loss: 1.0065 - disc_loss: 0.9681
# Epoch 12/100
# 24/24 [==============================] - 22s 900ms/step - gen_loss: 1.0050 - disc_loss: 0.9640
# Epoch 13/100
# 24/24 [==============================] - 22s 881ms/step - gen_loss: 0.9985 - disc_loss: 0.9596
# Epoch 14/100
# 24/24 [==============================] - 22s 891ms/step - gen_loss: 0.9892 - disc_loss: 0.9550
# Epoch 15/100
# 24/24 [==============================] - 22s 905ms/step - gen_loss: 0.9873 - disc_loss: 0.9503
# Epoch 16/100
# 24/24 [==============================] - 23s 932ms/step - gen_loss: 0.9796 - disc_loss: 0.9453
# Epoch 17/100
# 24/24 [==============================] - 22s 893ms/step - gen_loss: 0.9768 - disc_loss: 0.9402
# Epoch 18/100
# 24/24 [==============================] - 22s 885ms/step - gen_loss: 0.9703 - disc_loss: 0.9349
# Epoch 19/100
# 24/24 [==============================] - 22s 896ms/step - gen_loss: 0.9618 - disc_loss: 0.9294
# Epoch 20/100
# 24/24 [==============================] - 23s 931ms/step - gen_loss: 0.9581 - disc_loss: 0.9237
# Epoch 21/100
# 24/24 [==============================] - 22s 912ms/step - gen_loss: 0.9495 - disc_loss: 0.9178
# Epoch 22/100
# 24/24 [==============================] - 22s 892ms/step - gen_loss: 0.9451 - disc_loss: 0.9118
# Epoch 23/100
# 24/24 [==============================] - 22s 898ms/step - gen_loss: 0.9353 - disc_loss: 0.9055
# Epoch 24/100
# 24/24 [==============================] - 22s 909ms/step - gen_loss: 0.9292 - disc_loss: 0.8991
# Epoch 25/100
# 24/24 [==============================] - 22s 906ms/step - gen_loss: 0.9208 - disc_loss: 0.8925
# Epoch 26/100
# 24/24 [==============================] - 22s 908ms/step - gen_loss: 0.9130 - disc_loss: 0.8858
# Epoch 27/100
# 24/24 [==============================] - 23s 932ms/step - gen_loss: 0.9100 - disc_loss: 0.8788
# Epoch 28/100
# 24/24 [==============================] - 22s 892ms/step - gen_loss: 0.8991 - disc_loss: 0.8717
# Epoch 29/100
# 24/24 [==============================] - 22s 905ms/step - gen_loss: 0.8920 - disc_loss: 0.8645
# Epoch 30/100
# 24/24 [==============================] - 22s 914ms/step - gen_loss: 0.8843 - disc_loss: 0.8571
# Epoch 31/100
# 24/24 [==============================] - 22s 915ms/step - gen_loss: 0.8788 - disc_loss: 0.8495
# Epoch 32/100
# 24/24 [==============================] - 22s 924ms/step - gen_loss: 0.8655 - disc_loss: 0.8418
# Epoch 33/100
# 24/24 [==============================] - 22s 887ms/step - gen_loss: 0.8559 - disc_loss: 0.8340
# Epoch 34/100
# 24/24 [==============================] - 22s 899ms/step - gen_loss: 0.8471 - disc_loss: 0.8260
# Epoch 35/100
# 24/24 [==============================] - 22s 922ms/step - gen_loss: 0.8349 - disc_loss: 0.8179
# Epoch 36/100
# 24/24 [==============================] - 22s 901ms/step - gen_loss: 0.8288 - disc_loss: 0.8097
# Epoch 37/100
# 24/24 [==============================] - 22s 885ms/step - gen_loss: 0.8176 - disc_loss: 0.8013
# Epoch 38/100
# 24/24 [==============================] - 22s 892ms/step - gen_loss: 0.8127 - disc_loss: 0.7929
# Epoch 39/100
# 24/24 [==============================] - 23s 923ms/step - gen_loss: 0.7964 - disc_loss: 0.7844
# Epoch 40/100
# 24/24 [==============================] - 22s 889ms/step - gen_loss: 0.7905 - disc_loss: 0.7757
# Epoch 41/100
# 24/24 [==============================] - 22s 889ms/step - gen_loss: 0.7784 - disc_loss: 0.7670
# Epoch 42/100
# 24/24 [==============================] - 22s 892ms/step - gen_loss: 0.7711 - disc_loss: 0.7582
# Epoch 43/100
# 24/24 [==============================] - 22s 916ms/step - gen_loss: 0.7553 - disc_loss: 0.7494
# Epoch 44/100
# 24/24 [==============================] - 22s 896ms/step - gen_loss: 0.7442 - disc_loss: 0.7405
# Epoch 45/100
# 24/24 [==============================] - 22s 893ms/step - gen_loss: 0.7371 - disc_loss: 0.7315
# Epoch 46/100
# 24/24 [==============================] - 22s 900ms/step - gen_loss: 0.7246 - disc_loss: 0.7226
# Epoch 47/100
# 24/24 [==============================] - 22s 908ms/step - gen_loss: 0.7131 - disc_loss: 0.7135
# Epoch 48/100
# 24/24 [==============================] - 23s 933ms/step - gen_loss: 0.7040 - disc_loss: 0.7045
# Epoch 49/100
# 24/24 [==============================] - 22s 900ms/step - gen_loss: 0.6877 - disc_loss: 0.6955
# Epoch 50/100
# 24/24 [==============================] - 22s 911ms/step - gen_loss: 0.6792 - disc_loss: 0.6865
# Epoch 51/100
# 24/24 [==============================] - 22s 904ms/step - gen_loss: 0.6626 - disc_loss: 0.6776
# Epoch 52/100
# 24/24 [==============================] - 22s 906ms/step - gen_loss: 0.6539 - disc_loss: 0.6687
# Epoch 53/100
# 24/24 [==============================] - 22s 904ms/step - gen_loss: 0.6356 - disc_loss: 0.6597
# Epoch 54/100
# 24/24 [==============================] - 22s 911ms/step - gen_loss: 0.6265 - disc_loss: 0.6510
# Epoch 55/100
# 24/24 [==============================] - 22s 909ms/step - gen_loss: 0.6153 - disc_loss: 0.6422
# Epoch 56/100
# 24/24 [==============================] - 22s 896ms/step - gen_loss: 0.6014 - disc_loss: 0.6336
# Epoch 57/100
# 24/24 [==============================] - 22s 891ms/step - gen_loss: 0.5874 - disc_loss: 0.6251
# Epoch 58/100
# 24/24 [==============================] - 22s 927ms/step - gen_loss: 0.5760 - disc_loss: 0.6168
# Epoch 59/100
# 24/24 [==============================] - 22s 902ms/step - gen_loss: 0.5666 - disc_loss: 0.6086
# Epoch 60/100
# 24/24 [==============================] - 22s 888ms/step - gen_loss: 0.5511 - disc_loss: 0.6005
# Epoch 61/100
# 24/24 [==============================] - 21s 883ms/step - gen_loss: 0.5353 - disc_loss: 0.5927
# Epoch 62/100
# 24/24 [==============================] - 22s 919ms/step - gen_loss: 0.5240 - disc_loss: 0.5850
# Epoch 63/100
# 24/24 [==============================] - 22s 925ms/step - gen_loss: 0.5086 - disc_loss: 0.5776
# Epoch 64/100
# 24/24 [==============================] - 22s 886ms/step - gen_loss: 0.4933 - disc_loss: 0.5704
# Epoch 65/100
# 24/24 [==============================] - 21s 884ms/step - gen_loss: 0.4879 - disc_loss: 0.5637
# Epoch 66/100
# 24/24 [==============================] - 22s 906ms/step - gen_loss: 0.4655 - disc_loss: 0.5569
# Epoch 67/100
# 24/24 [==============================] - 22s 898ms/step - gen_loss: 0.4566 - disc_loss: 0.5506
# Epoch 68/100
# 24/24 [==============================] - 22s 896ms/step - gen_loss: 0.4414 - disc_loss: 0.5448
# Epoch 69/100
# 24/24 [==============================] - 21s 882ms/step - gen_loss: 0.4297 - disc_loss: 0.5391
# Epoch 70/100
# 24/24 [==============================] - 22s 902ms/step - gen_loss: 0.4132 - disc_loss: 0.5340
# Epoch 71/100
# 24/24 [==============================] - 22s 912ms/step - gen_loss: 0.3991 - disc_loss: 0.5291
# Epoch 72/100
# 24/24 [==============================] - 22s 881ms/step - gen_loss: 0.3887 - disc_loss: 0.5249
# Epoch 73/100
# 24/24 [==============================] - 21s 884ms/step - gen_loss: 0.3746 - disc_loss: 0.5211
# Epoch 74/100
# 24/24 [==============================] - 22s 898ms/step - gen_loss: 0.3601 - disc_loss: 0.5176
# Epoch 75/100
# 24/24 [==============================] - 22s 924ms/step - gen_loss: 0.3501 - disc_loss: 0.5147
# Epoch 76/100
# 24/24 [==============================] - 22s 917ms/step - gen_loss: 0.3372 - disc_loss: 0.5123
# Epoch 77/100
# 24/24 [==============================] - 22s 881ms/step - gen_loss: 0.3254 - disc_loss: 0.5102
# Epoch 78/100
# 24/24 [==============================] - 22s 889ms/step - gen_loss: 0.3164 - disc_loss: 0.5091
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-180d4a4c7393> in <cell line: 20>()
#      18     discriminator_loss,
#      19 )
# ---> 20 mel_gan.fit(
#      21     train_dataset.shuffle(200).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE), epochs=100
#      22 )
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1769             logs = None
#    1770             for epoch, iterator in data_handler.enumerate_epochs():
# -> 1771                 self.reset_metrics()
#    1772                 callbacks.on_epoch_begin(epoch)
#    1773                 with data_handler.catch_stop_iteration():
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in reset_metrics(self)
#    2677         return tf_utils.sync_to_numpy_or_python_type(all_outputs)
#    2678
# -> 2679     def reset_metrics(self):
#    2680         """Resets the state of all the metrics in the model.
#    2681
#
# KeyboardInterrupt:

# %%
# Splitting the dataset into training and testing splits
wavs = tf.io.gfile.glob("/content/drive/MyDrive/train_data_real/class_E/*.wav")
print(f"Number of audio files: {len(wavs)}")

# Mapper function for loading the audio. This function returns two instances of the wave
def preprocess(filename):
    audio = tf.audio.decode_wav(tf.io.read_file(filename), 1, DESIRED_SAMPLES).audio
    return audio


# Create tf.data.Dataset objects and apply preprocessing
train_dataset = tf.data.Dataset.from_tensor_slices((wavs,))
train_dataset = train_dataset.map(preprocess, num_parallel_calls=tf.data.AUTOTUNE)
train_dataset = train_dataset.map(lambda x: MelSpec()(x))
train_dataset = train_dataset.batch(1)
# Out:
# Number of audio files: 382

# %%
train_dataset
# Out:
# <_BatchDataset element_spec=TensorSpec(shape=(None, 103, 80), dtype=tf.float32, name=None)>

# %%
import os
import soundfile as sf

# %%
x=1
sr=52734
for audio in train_dataset:
  pred = generator.predict(audio, verbose=1)
  pred = pred.reshape((26368, 1))
  output_file = os.path.join("/content/drive/MyDrive/train_data_gen/class_E", f"{x}.wav")
  sf.write(output_file, pred, sr)
  x=x+1
# Out:
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
